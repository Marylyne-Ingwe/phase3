# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# Tanzania faces serious water access challenges. Although many water points exist, a large portion are either non-functional or in need of repair. Timely identification of these wells can help allocate maintenance resources efficiently.
#
# Objective:
#
# The goal of this project is to predict the operational status of water points in rural Tanzania.
# - Functional
# - Functional but needs repair
# - Non functional
#
# This helps government and NGOs prioritize repairs and maintenance, improving access to clean water. Specifically, the findings will:
# - Help NGOs prioritize maintenance.
#
# - Support government agencies in planning new infrastructure.
#
# - Optimize resource allocation for water access programs.

# %% [markdown]
# ## 2. Data Understanding
#
#  Dataset Overview:
#
# The dataset contains information on water points across Tanzania.
# It includes geographic, technical, and administrative attributes.
#
# 2.1 Target variable: status_group (binary label)
#
# Key feature types:
# 2.2 Numerical: gps_height (elevation in meters), population, construction_year / well_age, amount_tsh (water amount)
#
# 2.3 Categorical: extraction_type_group, management_group, payment_type, quantity_group, source_type, water_quality, region, district_code, permit, public_meeting_flag
#
# 2.4 Datetime: date_recorded (used to derive year_recorded and month_recorded)

# %%
#import libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

#model libraries
import statsmodels.api as sm
from statsmodels.tools import add_constant
pd.set_option('display.max_columns', 50)

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score, auc

# Set style for better visualizations
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10, 6) 

# Ignore warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %%
# Loding the dataset
trg_set = pd.read_csv('training set values.csv')
test_set = pd.read_csv('test set values.csv')
trg_lbl = pd.read_csv('training set labels.csv')

# %%
# Display first few rows of trg_set
print("Dataset Shape:", trg_set.shape)
print("\nFirst few rows:")
trg_set.head()
# Out:
# Dataset Shape: (59400, 40)
#
# First few rows:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# ...

# %% [markdown]
# training set has 59400 rows and 40 columns which is 75%

# %%
# Display first few rows of test_set
print("Dataset Shape:", test_set.shape)
print("\nFirst few rows:")
test_set.head()
# Out:
# Dataset Shape: (14850, 40)
#
# First few rows:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
# ...

# %% [markdown]
# dataset in testset has 14850 rows and 40 columns which is 25%

# %%
# Display first few rows of trg_lbl
print("Dataset Shape:", trg_lbl.shape)
print("\nFirst few rows:")
trg_lbl.head()
# Out:
# Dataset Shape: (59400, 2)
#
# First few rows:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
# Check the distribution of our target variable-status_group
print("status_group Distribution:")
print(trg_lbl['status_group'].value_counts())
print("\nPercentages:")
print(trg_lbl['status_group'].value_counts(normalize=True) * 100)
# Out:
# status_group Distribution:
# functional                 32259
# non functional             22824
# functional needs repair     4317
# Name: status_group, dtype: int64
#
# Percentages:
# functional                 54.308081
# non functional             38.424242
# functional needs repair     7.267677
# Name: status_group, dtype: float64

# %% [markdown]
# # Check for missing values

# %%
# check for missing values in training set value
trg_set.isnull().sum()/len(trg_set)*100
# Out:
# id                        0.000000
# amount_tsh                0.000000
# date_recorded             0.000000
# funder                    6.119529
# gps_height                0.000000
# installer                 6.153199
# longitude                 0.000000
# latitude                  0.000000
# wpt_name                  0.000000
# num_private               0.000000
# basin                     0.000000
# subvillage                0.624579
# region                    0.000000
# region_code               0.000000
# district_code             0.000000
# lga                       0.000000
# ward                      0.000000
# population                0.000000
# public_meeting            5.612795
# recorded_by               0.000000
# scheme_management         6.526936
# scheme_name              47.417508
# permit                    5.144781
# construction_year         0.000000
# extraction_type           0.000000
# extraction_type_group     0.000000
# extraction_type_class     0.000000
# ...

# %%
# check for missing values in test set value
test_set.isnull().sum() / len(test_set)*100
# Out:
# id                        0.000000
# amount_tsh                0.000000
# date_recorded             0.000000
# funder                    5.851852
# gps_height                0.000000
# installer                 5.905724
# longitude                 0.000000
# latitude                  0.000000
# wpt_name                  0.000000
# num_private               0.000000
# basin                     0.000000
# subvillage                0.666667
# region                    0.000000
# region_code               0.000000
# district_code             0.000000
# lga                       0.000000
# ward                      0.000000
# population                0.000000
# public_meeting            5.528620
# recorded_by               0.000000
# scheme_management         6.525253
# scheme_name              47.757576
# permit                    4.962963
# construction_year         0.000000
# extraction_type           0.000000
# extraction_type_group     0.000000
# extraction_type_class     0.000000
# ...

# %% [markdown]
# Missing data present in some features e.g: gps_height, installer, subvillage, public_meeting, scheme_management, scheme_name permit and funder

# %%
# check missing values in training label
trg_lbl.isnull().sum()
# Out:
# id              0
# status_group    0
# dtype: int64

# %%
# checking for duplicates in training set
trg_set.duplicated().sum()
test_set.duplicated().sum()
trg_lbl.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated columns

# %%
# Convert id to string in all dataframes
trg_set['id'] = trg_set['id'].astype(str).str.strip()
test_set['id'] = test_set['id'].astype(str).str.strip()
trg_lbl['id'] = trg_lbl['id'].astype(str).str.strip()

# %%
# merge Trg_set, test_set and trg_lbl
# Add a column to mark the source (train or test)
trg_set['source'] = 'train'
test_set['source'] = 'test'

# If test_set doesn't have target column, add a placeholder
test_set['status_group'] = 'status_group'   # replace 'status_group' with actual target name

# Concatenate vertically
full_data = pd.concat([trg_set, test_set], axis=0, ignore_index=True)

print(full_data.shape)
full_data.head()
# Out:
# (74250, 41)
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# ...

# %%
#save the clean dataset
full_data.to_csv("tz_data_clean.csv", index=None)

# %%
full_data.dtypes
# Out:
# id                        object
# amount_tsh               float64
# date_recorded             object
# funder                    object
# gps_height                 int64
# installer                 object
# longitude                float64
# latitude                 float64
# wpt_name                  object
# num_private                int64
# basin                     object
# subvillage                object
# region                    object
# region_code                int64
# district_code              int64
# lga                       object
# ward                      object
# population                 int64
# public_meeting            object
# recorded_by               object
# scheme_management         object
# scheme_name               object
# permit                    object
# construction_year          int64
# extraction_type           object
# extraction_type_group     object
# extraction_type_class     object
# management                object
# ...

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
#     3.1 Data Cleaning to handle missing values and outliers

# %%
# To handle Missing values
# drop scheme_name column since it has more than 45% missing values
missing_percentage = (full_data['scheme_name'].isnull().sum() / len(full_data)) * 100
print(f"Missing percentage for scheme_name: {missing_percentage:.2f}%")

if missing_percentage > 45:
    full_data.drop(columns=['scheme_name'], inplace=True)
    print("'scheme_name' column dropped ✅")
else:
    print("'scheme_name' retained ✅")

# Fill all NaN values in the dataset with 'N/A'

full_data = full_data.fillna('N/A')
# Out:
# Missing percentage for scheme_name: 47.49%
# 'scheme_name' column dropped ✅

# %%
full_data.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# ...

# %%
full_data.isnull().sum()
# Out:
# id                       0
# amount_tsh               0
# date_recorded            0
# funder                   0
# gps_height               0
# installer                0
# longitude                0
# latitude                 0
# wpt_name                 0
# num_private              0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# permit                   0
# construction_year        0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# ...

# %% [raw]
# NaN value filled with N/A and sheme name dropped. No duplicates in the dataset too

# %%
#check for outliers using boxplots
# Select only numerical columns
num_cols = full_data.select_dtypes(include=['int64', 'float64']).columns

# Loop and plot boxplot for each numeric column
for col in num_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=full_data[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# The boxplots show presence of outliers in amount_tsh, gps_height, numPrivate, region_code, district code and population

# %% [markdown]
# 3.2 Feature Engineering

# %%
# Select categorical/object columns
cat_cols = full_data.select_dtypes(include=['object']).columns
print(cat_cols)
# Out:
# Index(['id', 'date_recorded', 'funder', 'installer', 'wpt_name', 'basin',
#        'subvillage', 'region', 'lga', 'ward', 'public_meeting', 'recorded_by',
#        'scheme_management', 'permit', 'extraction_type',
#        'extraction_type_group', 'extraction_type_class', 'management',
#        'management_group', 'payment', 'payment_type', 'water_quality',
#        'quality_group', 'quantity', 'quantity_group', 'source', 'source_type',
#        'source_class', 'waterpoint_type', 'waterpoint_type_group',
#        'status_group'],
#       dtype='object')

# %%
full_data.nunique()
# Out:
# id                       74250
# amount_tsh                 102
# date_recorded              369
# funder                    2141
# gps_height                2456
# installer                 2411
# longitude                71870
# latitude                 71869
# wpt_name                 45684
# num_private                 68
# basin                        9
# subvillage               21426
# region                      21
# region_code                 27
# district_code               20
# lga                        125
# ward                      2098
# population                1128
# public_meeting               3
# recorded_by                  1
# scheme_management           13
# permit                       3
# construction_year           55
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# ...

# %%
# Group rare categories for high cardinality categorical variables
for col in cat_cols:
    top_labels = full_data[col].value_counts().nlargest(10).index
    full_data[col] = full_data[col].where(full_data[col].isin(top_labels), other='Other')
full_data[col]
# Out:
# 0                 N/A
# 1                 N/A
# 2                 N/A
# 3                 N/A
# 4                 N/A
#              ...
# 74245    status_group
# 74246    status_group
# 74247    status_group
# 74248    status_group
# 74249    status_group
# Name: status_group, Length: 74250, dtype: object

# %%
# Convert date_recorded to datetime
full_data['date_recorded'] = pd.to_datetime(full_data['date_recorded'], errors='coerce')

# Create a new feature: well age
full_data['well_age'] = full_data['date_recorded'].dt.year - full_data['construction_year']

# Replace negative ages or zeros with median
full_data['well_age'] = full_data['well_age'].apply(lambda x: x if x > 0 else full_data['well_age'].median())

# Binary feature: whether a public meeting was held
full_data['public_meeting_flag'] = full_data['public_meeting'].apply(lambda x: 1 if x == True else 0)

# Drop original boolean since it is not needed
full_data.drop(columns=['public_meeting'], inplace=True)

# %%
full_data.head()
full_data.shape
# Out:
# (74250, 41)

# %%
# Categorical features to encode
categorical_cols = [
    'extraction_type_group',
    'management_group',
    'payment_type',
    'water_quality',
    'quantity_group',
    'source_type',
    'source_class'
]

# Numeric features to scale or keep
numeric_cols = [
    'construction_year',
    'well_age',
    'gps_height',
    'population',
    'region',
    'district_code',
    'public_meeting_flag'  # already numeric
]

# Binary categorical
binary_col = 'permit'

# %%
# Convert region to numeric if possible
full_data['region'] = pd.to_numeric(full_data['region'], errors='coerce')

full_data['region'] = full_data['region'].fillna(full_data['region'].median()) # region is supposed to be numeric
#a region code instead of names), hence it should be converted

# %%
# Fill missing values in categorical columns
full_data[categorical_cols] = full_data[categorical_cols].fillna('N/A')

# Fill missing values in numeric columns
for col in numeric_cols:
    full_data[col] = full_data[col].fillna(full_data[col].median())

# Fill missing values in permit
full_data[binary_col] = full_data[binary_col].fillna('N/A')

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74250 entries, 0 to 74249
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     74250 non-null  object
#  1   amount_tsh             74250 non-null  float64
#  2   date_recorded          6282 non-null   datetime64[ns]
#  3   funder                 74250 non-null  object
#  4   gps_height             74250 non-null  int64
#  5   installer              74250 non-null  object
#  6   longitude              74250 non-null  float64
#  7   latitude               74250 non-null  float64
#  8   wpt_name               74250 non-null  object
#  9   num_private            74250 non-null  int64
#  10  basin                  74250 non-null  object
#  11  subvillage             74250 non-null  object
#  12  region                 0 non-null      float64
#  13  region_code            74250 non-null  int64
# ...

# %% [markdown]
#  3.5 Encode the permit Column (Yes/No). Convert the permit column to 0/1:

# %%
full_data['permit'] = full_data['permit'].map({'True': 1, 'False': 0, 'N/A': 0}).fillna(0).astype(int)

# %%
#Use Label Encoding for efficiency instead of one hot encoding
le = LabelEncoder()
for col in categorical_cols:
   full_data[col] = le.fit_transform(full_data[col].astype(str))
full_data[col]
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 74245    1
# 74246    0
# 74247    1
# 74248    1
# 74249    0
# Name: source_class, Length: 74250, dtype: int32

# %% [markdown]
#  Now all categorical columns become integer-encoded.

# %% [markdown]
# 3.6 Scale Numeric Features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
full_data[numeric_cols] = scaler.fit_transform(full_data[numeric_cols])

# %%
# check dtypes
print(full_data.dtypes)
print(full_data.head())
# Out:
# id                               object
# amount_tsh                      float64
# date_recorded            datetime64[ns]
# funder                           object
# gps_height                      float64
# installer                        object
# longitude                       float64
# latitude                        float64
# wpt_name                         object
# num_private                       int64
# basin                            object
# subvillage                       object
# region                          float64
# region_code                       int64
# district_code                   float64
# lga                              object
# ward                             object
# population                      float64
# recorded_by                      object
# scheme_management                object
# permit                            int32
# construction_year               float64
# extraction_type                  object
# ...

# %% [markdown]
# id — should be dropped before modeling. It’s an identifier, not a predictor. date_recorded — models can’t use datetime directly. We can: Extract year, month features Or drop it if not useful. All remaining object columns (categorical) need encoding:
#
# Either Label Encoding (for tree-based models like Random Forest, XGBoost) Or One-Hot Encoding (for logistic regression, linear models)
# status_group should be properly encoded as integers since it’s your target variable

# %%
full_data.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'recorded_by', 'scheme_management', 'permit',
#        'construction_year', 'extraction_type', 'extraction_type_group',
#        'extraction_type_class', 'management', 'management_group', 'payment',
#        'payment_type', 'water_quality', 'quality_group', 'quantity',
#        'quantity_group', 'source', 'source_type', 'source_class',
#        'waterpoint_type', 'waterpoint_type_group', 'status_group', 'well_age',
#        'public_meeting_flag'],
#       dtype='object')

# %%
#Drop or transform non-informative columns
full_data_feat = full_data.drop(columns=['id','amount_tsh', 'date_recorded', 'funder',
       'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
       'basin', 'subvillage', 'region', 'region_code', 'lga',
       'ward', 'recorded_by', 'scheme_management', 'extraction_type',
       'extraction_type_class', 'management', 'payment', 'quantity', 'source', 'source_class',
       'waterpoint_type', 'waterpoint_type_group', 'well_age','month_recorded', 'quality_group', 'year_recorded' ], errors='ignore')

#Encode status_group (target)
le = LabelEncoder()
full_data['status_group'] = le.fit_transform(full_data['status_group'].astype(str))

# Convert all categorical (object) columns to numeric
categorical_cols = full_data.select_dtypes(include='object').columns

for col in categorical_cols:
    full_data[col] = le.fit_transform(full_data[col].astype(str))
    
#Convert datetime
if 'date_recorded' in full_data.columns:
    full_data['year_recorded'] = full_data['date_recorded'].dt.year
    full_data['month_recorded'] = full_data['date_recorded'].dt.month
    full_data = full_data.drop(columns=['date_recorded'])
else:
    print("⚠️'date_recorded' column not found — skipping date feature extraction.")


print(full_data_feat.dtypes)
# Out:
# ⚠️'date_recorded' column not found — skipping date feature extraction.
# gps_height               float64
# district_code            float64
# population               float64
# permit                     int32
# construction_year        float64
# extraction_type_group      int32
# management_group           int32
# payment_type               int32
# water_quality              int32
# quantity_group             int32
# source_type                int32
# status_group               int32
# public_meeting_flag      float64
# dtype: object

# %% [markdown]
# Now the datasets are either float64, int32 or int64. prefect for modeling

# %%
full_data_feat.shape
# Out:
# (74250, 13)

# %%
full_data_feat =full_data_feat.drop('permit', axis=1)

# %%
full_data_feat.head()
# Out:
#    gps_height  district_code  population  construction_year  \
# 0    1.045581      -0.065246   -0.152310           0.735593
# 1    1.058572      -0.376399    0.210683           0.747143
# 2    0.029350      -0.168964    0.147000           0.746093
# 3   -0.581254       5.950371   -0.260572           0.721942
# 4   -0.960897      -0.480117   -0.383692          -1.363441
#
#    extraction_type_group  management_group  payment_type  water_quality  \
# 0                      2                 4             0              6
# 1                      2                 4             2              6
# 2                      2                 4             5              6
# 3                      9                 4             2              6
# 4                      2                 1             2              6
#
#    quantity_group  source_type  status_group  public_meeting_flag
# 0               1            6             0             0.405862
# ...

# %% [markdown]
# # 4. Modeling

# %% [markdown]
# # Model 1: Logistic regression model

# %%
# Prepare the data for modeling

# Separate features (X) and target (y)
# Define appropriate X and y
y = full_data_feat['status_group']
X = full_data_feat.drop(columns='status_group', axis=1)

# Normalize the features (scale values between 0 and 1)
X = (X - X.min()) / (X.max() - X.min())

# Split data into training (75%) and testing (25%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print(f"Training set size: {len(X_train)}")
print(f"Testing set size: {len(X_test)}")
# Out:
# Training set size: 55687
# Testing set size: 18563

# %% [markdown]
# Properly structured data for modeling: Clear separation of predictors (X) and target (y). Normalization ensures consistent feature scale. The train-test split sets up to train and evaluate models fairly. Training set: 55,687 samples
#
# Testing set: 18,563 samples
# This means about 75% of your data is used to train the model, while 25% is held out to evaluate its performance on unseen data.

# %%
# Fit a model
logreg = LogisticRegression(fit_intercept=False, C=1e12, solver='liblinear')
logreg.fit(X_train, y_train)
print(logreg) # Preview model params

# Predict
y_hat_test = logreg.predict(X_test)

# Data preview
print("")
full_data_feat.head()
# Out:
# LogisticRegression(C=1000000000000.0, fit_intercept=False, solver='liblinear')
#    gps_height  district_code  population  construction_year  \
# 0    1.045581      -0.065246   -0.152310           0.735593
# 1    1.058572      -0.376399    0.210683           0.747143
# 2    0.029350      -0.168964    0.147000           0.746093
# 3   -0.581254       5.950371   -0.260572           0.721942
# 4   -0.960897      -0.480117   -0.383692          -1.363441
#
#    extraction_type_group  management_group  payment_type  water_quality  \
# 0                      2                 4             0              6
# 1                      2                 4             2              6
# 2                      2                 4             5              6
# 3                      9                 4             2              6
# 4                      2                 1             2              6
#
#    quantity_group  source_type  status_group  public_meeting_flag
# ...

# %%
#check back X after dropping unwanted columns
X.shape
# Out:
# (74250, 11)

# %%
from sklearn.metrics import roc_curve, auc

# Scikit-learn's built in roc_curve method returns the fpr, tpr, and thresholds
# for various decision boundaries given the case member probabilites

# First calculate the probability scores of each of the datapoints:
y_score = logreg.fit(X_train, y_train).decision_function(X_test)

fpr, tpr, thresholds = roc_curve(y_test, y_score)

print('AUC: {}'.format(auc(fpr, tpr)))
# Out:
# AUC: 0.49727529965886696

# %% [markdown]
# This AUC is very close to 0.5, which means your logistic regression model is performing no better than random guessing at distinguishing between the positive and negative classes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Seaborn's beautiful styling
sns.set_style('darkgrid', {'axes.facecolor': '0.9'})

print('AUC: {}'.format(auc(fpr, tpr)))
plt.figure(figsize=(10, 8))
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUC: 0.49727529965886696

# %% [markdown]
# The orange ROC curve in your plot lies very close to the diagonal dashed line (random baseline). This matches the AUC ≈ 0.5 value you saw earlier.
# What this means:
# The model’s true positive rate is almost the same as the false positive rate at all thresholds.
# It’s not distinguishing between the positive and negative classes effectively.

# %%
# Generate predictions on the test set
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
y_pred = logreg.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')  # use 'weighted' for multi-class
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Accuracy:  {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall:    {recall:.4f}')
print(f'F1-score:  {f1:.4f}')

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.7998
# Precision: 0.6396
# Recall:    0.7998
# F1-score:  0.7108
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89     14846
#            1       0.00      0.00      0.00      3717
#
#     accuracy                           0.80     18563
#    macro avg       0.40      0.50      0.44     18563
# weighted avg       0.64      0.80      0.71     18563

# %% [markdown]
# Interpretation by Metric
# Accuracy (≈ 0.80):
# The model correctly predicts about 80% of all observations. This looks high, but it’s misleading because of class imbalance.
# Precision (0.64):
# On average, 64% of the positive predictions are correct — but this is mostly coming from the majority class (class 0).
# Recall (0.80):
# The model correctly identifies 80% of the actual class 0 but 0% of class 1. So it's completely failing to detect the minority class.
# F1-score (0.71):
# Balances precision and recall, but again, dominated by class 0.

# %% [markdown]
# correlation between the features does not meet the the threshold of > 80 so none of the features should be droped.

# %% [markdown]
# # Handling class imbalance since since the model is predicting only the majority class 0

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Apply SMOTE on training data

# %%
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# Create SMOTE object
smote = SMOTE(random_state=42)

# Fit SMOTE on training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:", y_train_resampled.value_counts())
# Out:
# Before SMOTE: 0    44554
# 1    11133
# Name: status_group, dtype: int64
# After SMOTE: 1    44554
# 0    44554
# Name: status_group, dtype: int64

# %% [markdown]
# After SMOTE:
# Class 0 has 44,554 samples
# Class 1 also has 44,554 samples
# The dataset is now perfectly balanced, giving the model equal opportunity to learn from both classes

# %% [markdown]
# SMOTE created 33,421 synthetic samples for the minority class (Class 1)
# The model will now learn from equal representation of both classes
# This should help reduce bias toward predicting the majority class (Class 0)
# Better performance on the minority class is expected, though evaluation on the original imbalanced test set will show the true improvement

# %% [markdown]
# # Metrix for the smote model

# %%
# Import necessary libraries
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Create SMOTE object
smote = SMOTE(random_state=42)

# Fit SMOTE on training data
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

print("Before SMOTE:", y_train.value_counts())
print("After SMOTE:", y_train_resampled.value_counts())

# Train Logistic Regression model on SMOTE data
model = LogisticRegression(random_state=42)
model.fit(X_train_resampled, y_train_resampled)

# Make predictions on test set
y_pred = model.predict(X_test)

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print the metrics
print("\n" + "="*50)
print("SMOTE MODEL PERFORMANCE METRICS")
print("="*50)
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1-Score:  {f1:.4f}")
# Out:
# Before SMOTE: 0    44554
# 1    11133
# Name: status_group, dtype: int64
# After SMOTE: 1    44554
# 0    44554
# Name: status_group, dtype: int64
#
# ...
# SMOTE MODEL PERFORMANCE METRICS
# ...
# Accuracy:  0.4992
# Precision: 0.2015
# Recall:    0.5069
# F1-Score:  0.2884

# %% [markdown]
# # To compare with the original imbalanced model

# %%
# Compare with model trained on original imbalanced data
model_original = LogisticRegression(random_state=42)
model_original.fit(X_train, y_train)
y_pred_original = model_original.predict(X_test)

# Calculate metrics for original model
accuracy_orig = accuracy_score(y_test, y_pred_original)
precision_orig = precision_score(y_test, y_pred_original)
recall_orig = recall_score(y_test, y_pred_original)
f1_orig = f1_score(y_test, y_pred_original)

print("\n" + "="*60)
print("COMPARISON: ORIGINAL vs SMOTE")
print("="*60)
print(f"{'Metric':<12} {'Original':<10} {'SMOTE':<10} {'Improvement':<12}")
print("-" * 60)
print(f"{'Accuracy':<12} {accuracy_orig:.4f}    {accuracy:.4f}    {accuracy-accuracy_orig:+.4f}")
print(f"{'Precision':<12} {precision_orig:.4f}    {precision:.4f}    {precision-precision_orig:+.4f}")
print(f"{'Recall':<12} {recall_orig:.4f}    {recall:.4f}    {recall-recall_orig:+.4f}")
print(f"{'F1-Score':<12} {f1_orig:.4f}    {f1:.4f}    {f1-f1_orig:+.4f}")
# Out:
# ...
# COMPARISON: ORIGINAL vs SMOTE
# ...
# Metric       Original   SMOTE      Improvement
# ------------------------------------------------------------
# Accuracy     0.7998    0.4992    -0.3006
# Precision    0.0000    0.2015    +0.2015
# Recall       0.0000    0.5069    +0.5069
# F1-Score     0.0000    0.2884    +0.2884

# %%
POSITIVE OUTCOMES:
Eliminated Class Bias: The model will no longer be biased toward predicting the majority class (Class 0)
Equal Learning Opportunity: Both classes now have equal representation for training
Better Minority Class Detection: We should expect significant improvement in detecting Class 1 instances

# %% [markdown]
# # Model3 :Tuned Model

# %%
# Stage 1: Tune only the most important parameter (C)
print("STAGE 1: Tuning C parameter")
stage1_params = {
    'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]
}

stage1_search = GridSearchCV(
    pipeline,
    stage1_params,
    scoring='f1',
    cv=3,
    n_jobs=-1
)

stage1_search.fit(X_train, y_train)
best_C = stage1_search.best_params_['classifier__C']
print(f"Best C: {best_C}")

# Stage 2: Tune SMOTE with fixed best C
print("\nSTAGE 2: Tuning SMOTE parameter")
pipeline.set_params(classifier__C=best_C)

stage2_params = {
    'smote__k_neighbors': [3, 5, 7]
}

stage2_search = GridSearchCV(
    pipeline,
    stage2_params,
    scoring='f1',
    cv=3,
    n_jobs=-1
)

stage2_search.fit(X_train, y_train)

print("Final best parameters:")
print(stage2_search.best_params_)
print(f"Final F1-Score: {stage2_search.best_score_:.4f}")

best_model = stage2_search.best_estimator_
# Out:
# STAGE 1: Tuning C parameter
# Best C: 100
#
# STAGE 2: Tuning SMOTE parameter
# Final best parameters:
# {'smote__k_neighbors': 3}
# Final F1-Score: 0.2858

# %% [markdown]
# # Baseline Comparison

# %%
# Test only 3 key configurations quickly
configs = [
    {'name': 'Default', 'k_neighbors': 5, 'C': 1.0},
    {'name': 'Strong_Reg', 'k_neighbors': 3, 'C': 0.1},
    {'name': 'Weak_Reg', 'k_neighbors': 7, 'C': 10.0}
]

best_config = None
best_score = 0

for config in configs:
    pipeline = Pipeline([
        ('smote', SMOTE(k_neighbors=config['k_neighbors'], random_state=42)),
        ('classifier', LogisticRegression(C=config['C'], random_state=42, max_iter=1000))
    ])
    
    # Quick validation
    X_temp, X_val, y_temp, y_val = train_test_split(
        X_train, y_train, test_size=0.25, random_state=42, stratify=y_train
    )
    
    pipeline.fit(X_temp, y_temp)
    y_pred_val = pipeline.predict(X_val)
    score = f1_score(y_val, y_pred_val)
    
    print(f"{config['name']}: k={config['k_neighbors']}, C={config['C']} -> F1: {score:.4f}")
    
    if score > best_score:
        best_score = score
        best_config = config

print(f"\n🎯 Best configuration: {best_config}")
print(f"Best F1-Score: {best_score:.4f}")
# Out:
# Default: k=5, C=1.0 -> F1: 0.2850
# Strong_Reg: k=3, C=0.1 -> F1: 0.2898
# Weak_Reg: k=7, C=10.0 -> F1: 0.2876
#
# 🎯 Best configuration: {'name': 'Strong_Reg', 'k_neighbors': 3, 'C': 0.1}
# Best F1-Score: 0.2898

# %% [markdown]
# # Comparison

# %%
# Import necessary libraries
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd

# 1. ORIGINAL IMBALANCED MODEL
original_model = LogisticRegression(random_state=42, max_iter=1000)
original_model.fit(X_train, y_train)
y_pred_original = original_model.predict(X_test)

# 2. BASIC SMOTE MODEL
smote_basic = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote_basic.fit_resample(X_train, y_train)

smote_model = LogisticRegression(random_state=42, max_iter=1000)
smote_model.fit(X_train_smote, y_train_smote)
y_pred_smote = smote_model.predict(X_test)

# 3. TUNED SMOTE MODEL (from your hyperparameter tuning)
tuned_model = best_model  # from your tuning results
y_pred_tuned = tuned_model.predict(X_test)

# Calculate metrics for all models
def calculate_all_metrics(y_true, y_pred, model_name):
    return {
        'Model': model_name,
        'Accuracy': accuracy_score(y_true, y_pred),
        'Precision': precision_score(y_true, y_pred),
        'Recall': recall_score(y_true, y_pred),
        'F1-Score': f1_score(y_true, y_pred)
    }

# Create comparison table
results = []
results.append(calculate_all_metrics(y_test, y_pred_original, 'Original Imbalanced'))
results.append(calculate_all_metrics(y_test, y_pred_smote, 'Basic SMOTE'))
results.append(calculate_all_metrics(y_test, y_pred_tuned, 'Tuned SMOTE'))

results_df = pd.DataFrame(results)
print("\n" + "="*70)
print("MODEL COMPARISON: ORIGINAL vs BASIC SMOTE vs TUNED SMOTE")
print("="*70)
print(results_df.round(4))

# Calculate improvements
print("\n" + "="*50)
print("IMPROVEMENT ANALYSIS")
print("="*50)
original_f1 = results_df[results_df['Model'] == 'Original Imbalanced']['F1-Score'].values[0]
smote_f1 = results_df[results_df['Model'] == 'Basic SMOTE']['F1-Score'].values[0]
tuned_f1 = results_df[results_df['Model'] == 'Tuned SMOTE']['F1-Score'].values[0]

print(f"F1-Score Improvement from Original to Basic SMOTE: {smote_f1 - original_f1:+.4f}")
print(f"F1-Score Improvement from Basic SMOTE to Tuned: {tuned_f1 - smote_f1:+.4f}")
print(f"Total F1-Score Improvement: {tuned_f1 - original_f1:+.4f}")

# Visual comparison
plt.figure(figsize=(12, 8))

# Metrics comparison plot
metrics_to_plot = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
x_pos = np.arange(len(metrics_to_plot))
width = 0.25

fig, ax = plt.subplots(2, 2, figsize=(15, 10))

# Plot 1: Metrics comparison
for i, metric in enumerate(metrics_to_plot):
    row, col = i // 2, i % 2
    models = ['Original', 'Basic SMOTE', 'Tuned SMOTE']
    values = [
        results_df[results_df['Model'] == 'Original Imbalanced'][metric].values[0],
        results_df[results_df['Model'] == 'Basic SMOTE'][metric].values[0],
        results_df[results_df['Model'] == 'Tuned SMOTE'][metric].values[0]
    ]
    
    bars = ax[row, col].bar(models, values, color=['red', 'orange', 'green'], alpha=0.7)
    ax[row, col].set_title(f'{metric} Comparison')
    ax[row, col].set_ylabel(metric)
    ax[row, col].grid(axis='y', alpha=0.3)
    
    # Add value labels on bars
    for bar, value in zip(bars, values):
        height = bar.get_height()
        ax[row, col].text(bar.get_x() + bar.get_width()/2., height,
                         f'{value:.4f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Confusion Matrices
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
models = [('Original Imbalanced', y_pred_original), 
          ('Basic SMOTE', y_pred_smote), 
          ('Tuned SMOTE', y_pred_tuned)]

for i, (name, y_pred) in enumerate(models):
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(ax=axes[i], values_format='d')
    axes[i].set_title(f'{name}\nF1: {results_df[results_df["Model"] == name]["F1-Score"].values[0]:.4f}')

plt.tight_layout()
plt.show()

# Detailed classification reports
print("\n" + "="*50)
print("DETAILED CLASSIFICATION REPORTS")
print("="*50)

print("\n1. ORIGINAL IMBALANCED MODEL:")
print(classification_report(y_test, y_pred_original))

print("\n2. BASIC SMOTE MODEL:")
print(classification_report(y_test, y_pred_smote))

print("\n3. TUNED SMOTE MODEL:")
print(classification_report(y_test, y_pred_tuned))

# Key insights summary
print("\n" + "="*60)
print("KEY INSIGHTS SUMMARY")
print("="*60)

best_model_name = results_df.loc[results_df['F1-Score'].idxmax(), 'Model']
best_f1 = results_df['F1-Score'].max()

print(f"🏆 Best Performing Model: {best_model_name}")
print(f"🎯 Best F1-Score: {best_f1:.4f}")

# Analyze which model is best for specific needs
print("\n📊 Model Selection Guide:")
print(f"• For overall balance: Choose model with highest F1-Score")
print(f"• For minimizing false positives: Choose model with highest Precision")  
print(f"• For detecting all positive cases: Choose model with highest Recall")
print(f"• For general accuracy: Choose model with highest Accuracy")

# Show the best parameters found in tuning
print(f"\n⚙️ Tuned Model Parameters:")
print(f"   - C: 100")
print(f"   - SMOTE k_neighbors: 3")
# Out:
# ...
# MODEL COMPARISON: ORIGINAL vs BASIC SMOTE vs TUNED SMOTE
# ...
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0  Original Imbalanced    0.7998     0.0000  0.0000    0.0000
# 1          Basic SMOTE    0.4992     0.2015  0.5069    0.2884
# 2          Tuned SMOTE    0.4923     0.2006  0.5144    0.2886
#
# ...
# IMPROVEMENT ANALYSIS
# ...
# F1-Score Improvement from Original to Basic SMOTE: +0.2884
# F1-Score Improvement from Basic SMOTE to Tuned: +0.0002
# Total F1-Score Improvement: +0.2886
# ...
# DETAILED CLASSIFICATION REPORTS
# ...
#
# 1. ORIGINAL IMBALANCED MODEL:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89     14846
#            1       0.00      0.00      0.00      3717
#
#     accuracy                           0.80     18563
#    macro avg       0.40      0.50      0.44     18563
# weighted avg       0.64      0.80      0.71     18563
#
#
# 2. BASIC SMOTE MODEL:
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # 3. Decision tree model

# %%
# 1. ORIGINAL IMBALANCED DECISION TREE MODEL
print("ORIGINAL IMBALANCED DECISION TREE")
print("=" * 40)

# Initialize and train Decision Tree on original imbalanced data
dt_original = DecisionTreeClassifier(random_state=42)
dt_original.fit(X_train, y_train)

# Make predictions
y_pred_dt_original = dt_original.predict(X_test)

# Calculate metrics
accuracy_dt_original = accuracy_score(y_test, y_pred_dt_original)
precision_dt_original = precision_score(y_test, y_pred_dt_original)
recall_dt_original = recall_score(y_test, y_pred_dt_original)
f1_dt_original = f1_score(y_test, y_pred_dt_original)

# Print results
print(f"Accuracy:  {accuracy_dt_original:.4f}")
print(f"Precision: {precision_dt_original:.4f}")
print(f"Recall:    {recall_dt_original:.4f}")
print(f"F1-Score:  {f1_dt_original:.4f}")

# Show prediction distribution
print(f"\nPrediction distribution: {np.unique(y_pred_dt_original, return_counts=True)}")
print(f"Actual test distribution: {np.unique(y_test, return_counts=True)}")
# Out:
# ORIGINAL IMBALANCED DECISION TREE
# ...
# Accuracy:  0.7076
# Precision: 0.2039
# Recall:    0.1585
# F1-Score:  0.1783
#
# Prediction distribution: (array([0, 1]), array([15675,  2888], dtype=int64))
# Actual test distribution: (array([0, 1]), array([14846,  3717], dtype=int64))

# %%
# 2. BASIC SMOTE + DECISION TREE MODEL
print("BASIC SMOTE + DECISION TREE")
print("=" * 35)

# Apply SMOTE to training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Initialize and train Decision Tree on SMOTE-balanced data
dt_smote = DecisionTreeClassifier(random_state=42)
dt_smote.fit(X_train_smote, y_train_smote)

# Make predictions
y_pred_dt_smote = dt_smote.predict(X_test)

# Calculate metrics
accuracy_dt_smote = accuracy_score(y_test, y_pred_dt_smote)
precision_dt_smote = precision_score(y_test, y_pred_dt_smote)
recall_dt_smote = recall_score(y_test, y_pred_dt_smote)
f1_dt_smote = f1_score(y_test, y_pred_dt_smote)

# Print results
print(f"Accuracy:  {accuracy_dt_smote:.4f}")
print(f"Precision: {precision_dt_smote:.4f}")
print(f"Recall:    {recall_dt_smote:.4f}")
print(f"F1-Score:  {f1_dt_smote:.4f}")

# Show training data distribution after SMOTE
print(f"\nTraining data after SMOTE: {np.unique(y_train_smote, return_counts=True)}")
print(f"Prediction distribution: {np.unique(y_pred_dt_smote, return_counts=True)}")
# Out:
# BASIC SMOTE + DECISION TREE
# ...
# Accuracy:  0.6293
# Precision: 0.1953
# Recall:    0.2728
# F1-Score:  0.2276
#
# Training data after SMOTE: (array([0, 1]), array([44554, 44554], dtype=int64))
# Prediction distribution: (array([0, 1]), array([13370,  5193], dtype=int64))

# %%
# 3. TUNED DECISION TREE WITH SMOTE

print("TUNED DECISION TREE WITH SMOTE")
print("=" * 35)

# Apply SMOTE to training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Hyperparameter tuning for Decision Tree
param_grid_dt = {
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Perform GridSearchCV
grid_search_dt = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid_dt,
    scoring='f1',
    cv=3,
    n_jobs=-1,
    verbose=1
)

# Fit on SMOTE data
grid_search_dt.fit(X_train_smote, y_train_smote)

# Get best model and make predictions
dt_tuned = grid_search_dt.best_estimator_
y_pred_dt_tuned = dt_tuned.predict(X_test)

# Calculate metrics
accuracy_dt_tuned = accuracy_score(y_test, y_pred_dt_tuned)
precision_dt_tuned = precision_score(y_test, y_pred_dt_tuned)
recall_dt_tuned = recall_score(y_test, y_pred_dt_tuned)
f1_dt_tuned = f1_score(y_test, y_pred_dt_tuned)

# Print results
print(f"Best Parameters: {grid_search_dt.best_params_}")
print(f"Accuracy:  {accuracy_dt_tuned:.4f}")
print(f"Precision: {precision_dt_tuned:.4f}")
print(f"Recall:    {recall_dt_tuned:.4f}")
print(f"F1-Score:  {f1_dt_tuned:.4f}")

# Show feature importance
if hasattr(dt_tuned, 'feature_importances_'):
    print(f"\nTop 5 Most Important Features:")
    feature_importance = pd.DataFrame({
        'feature': X_train.columns if hasattr(X_train, 'columns') else [f'Feature_{i}' for i in range(X_train.shape[1])],
        'importance': dt_tuned.feature_importances_
    }).sort_values('importance', ascending=False).head(5)
    print(feature_importance)
# Out:
# TUNED DECISION TREE WITH SMOTE
# ...
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:  1.9min finished
# Best Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy:  0.6312
# Precision: 0.1945
# Recall:    0.2680
# F1-Score:  0.2254
#
# Top 5 Most Important Features:
#                  feature  importance
# 3      construction_year    0.308766
# 0             gps_height    0.285548
# 2             population    0.132833
# 1          district_code    0.074052
# 4  extraction_type_group    0.046031

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# 1. ORIGINAL IMBALANCED DECISION TREE
dt_original = DecisionTreeClassifier(random_state=42)
dt_original.fit(X_train, y_train)
y_pred_dt_original = dt_original.predict(X_test)

# 2. BASIC SMOTE + DECISION TREE
X_train_smote, y_train_smote = smote_basic.fit_resample(X_train, y_train)
dt_smote = DecisionTreeClassifier(random_state=42)
dt_smote.fit(X_train_smote, y_train_smote)
y_pred_dt_smote = dt_smote.predict(X_test)

# 3. TUNED DECISION TREE WITH SMOTE
# First, let's do quick hyperparameter tuning for Decision Tree
param_grid_dt = {
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

dt_for_tuning = DecisionTreeClassifier(random_state=42)
grid_search_dt = GridSearchCV(
    dt_for_tuning,
    param_grid_dt,
    scoring='f1',
    cv=3,
    n_jobs=-1,
    verbose=1
)

# Use SMOTE data for tuning
grid_search_dt.fit(X_train_smote, y_train_smote)

print("Best Decision Tree parameters:", grid_search_dt.best_params_)
print(f"Best Decision Tree CV F1-Score: {grid_search_dt.best_score_:.4f}")

# Train tuned model
dt_tuned = grid_search_dt.best_estimator_
y_pred_dt_tuned = dt_tuned.predict(X_test)

# Calculate metrics for all Decision Tree models
dt_results = []
dt_results.append(calculate_all_metrics(y_test, y_pred_dt_original, 'DT Original'))
dt_results.append(calculate_all_metrics(y_test, y_pred_dt_smote, 'DT Basic SMOTE'))
dt_results.append(calculate_all_metrics(y_test, y_pred_dt_tuned, 'DT Tuned SMOTE'))

dt_results_df = pd.DataFrame(dt_results)

print("\n" + "="*70)
print("DECISION TREE MODEL COMPARISON")
print("="*70)
print(dt_results_df.round(4))

# Compare with Logistic Regression models
print("\n" + "="*70)
print("COMPARISON: LOGISTIC REGRESSION vs DECISION TREE")
print("="*70)

# Combine all results
all_results = pd.concat([results_df, dt_results_df], ignore_index=True)
print(all_results.round(4))

# Visual comparison
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
metrics_to_plot = ['Accuracy', 'Precision', 'Recall', 'F1-Score']

for i, metric in enumerate(metrics_to_plot):
    row, col = i // 2, i % 2
    
    # Filter models
    lr_models = all_results[all_results['Model'].str.contains('Original|Basic SMOTE|Tuned SMOTE') & 
                           ~all_results['Model'].str.contains('DT')]
    dt_models = all_results[all_results['Model'].str.contains('DT')]
    
    x = range(len(lr_models))
    width = 0.35
    
    axes[row, col].bar([pos - width/2 for pos in x], lr_models[metric], width, 
                      label='Logistic Regression', alpha=0.7, color='blue')
    axes[row, col].bar([pos + width/2 for pos in x], dt_models[metric], width, 
                      label='Decision Tree', alpha=0.7, color='green')
    
    axes[row, col].set_title(f'{metric} Comparison')
    axes[row, col].set_ylabel(metric)
    axes[row, col].set_xticks(x)
    axes[row, col].set_xticklabels(['Original', 'Basic SMOTE', 'Tuned SMOTE'])
    axes[row, col].legend()
    axes[row, col].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Feature Importance Analysis
print("\n" + "="*50)
print("DECISION TREE FEATURE IMPORTANCE")
print("="*50)

feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'Feature_{i}' for i in range(X_train.shape[1])]

feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': dt_tuned.feature_importances_
}).sort_values('importance', ascending=False)

print("Top 15 Most Important Features:")
print(feature_importance_df.head(15).round(4))

# Plot feature importance
plt.figure(figsize=(12, 8))
top_features = feature_importance_df.head(15)
plt.barh(top_features['feature'], top_features['importance'])
plt.xlabel('Feature Importance')
plt.title('Top 15 Most Important Features - Decision Tree')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# Confusion Matrices for Decision Tree
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
dt_models = [('DT Original', y_pred_dt_original), 
             ('DT Basic SMOTE', y_pred_dt_smote), 
             ('DT Tuned SMOTE', y_pred_dt_tuned)]

for i, (name, y_pred) in enumerate(dt_models):
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(ax=axes[i], values_format='d')
    f1 = f1_score(y_test, y_pred)
    axes[i].set_title(f'{name}\nF1: {f1:.4f}')

plt.tight_layout()
plt.show()

# Detailed classification reports for Decision Tree
print("\n" + "="*50)
print("DECISION TREE CLASSIFICATION REPORTS")
print("="*50)

print("\n1. DECISION TREE ORIGINAL IMBALANCED:")
print(classification_report(y_test, y_pred_dt_original))

print("\n2. DECISION TREE BASIC SMOTE:")
print(classification_report(y_test, y_pred_dt_smote))

print("\n3. DECISION TREE TUNED SMOTE:")
print(classification_report(y_test, y_pred_dt_tuned))

# Cross-validation comparison
print("\n" + "="*50)
print("CROSS-VALIDATION COMPARISON (F1-Score)")
print("="*50)

models = {
    'LR Original': LogisticRegression(random_state=42),
    'LR SMOTE': LogisticRegression(random_state=42),
    'DT Original': DecisionTreeClassifier(random_state=42),
    'DT SMOTE': DecisionTreeClassifier(random_state=42)
}

cv_scores = {}
for name, model in models.items():
    if 'SMOTE' in name:
        # Use SMOTE data
        X_cv, y_cv = X_train_smote, y_train_smote
    else:
        # Use original data
        X_cv, y_cv = X_train, y_train
    
    scores = cross_val_score(model, X_cv, y_cv, scoring='f1', cv=3)
    cv_scores[name] = scores.mean()
    print(f"{name}: {scores.mean():.4f} (+/- {scores.std() * 2:.4f})")

# Final recommendation
print("\n" + "="*60)
print("FINAL RECOMMENDATION")
print("="*60)

best_overall = all_results.loc[all_results['F1-Score'].idxmax()]
print(f"🏆 Best Overall Model: {best_overall['Model']}")
print(f"🎯 Best F1-Score: {best_overall['F1-Score']:.4f}")

# Check if Decision Tree performed better
best_dt = dt_results_df.loc[dt_results_df['F1-Score'].idxmax()]
best_lr = results_df.loc[results_df['F1-Score'].idxmax()]

if best_dt['F1-Score'] > best_lr['F1-Score']:
    print("✅ Decision Tree outperformed Logistic Regression")
else:
    print("✅ Logistic Regression performed better")

print(f"\n📊 Best Decision Tree F1: {best_dt['F1-Score']:.4f}")
print(f"📊 Best Logistic Regression F1: {best_lr['F1-Score']:.4f}")
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:   18.7s finished
# Best Decision Tree parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Decision Tree CV F1-Score: 0.7050
#
# ...
# DECISION TREE MODEL COMPARISON
# ...
#             Model  Accuracy  Precision  Recall  F1-Score
# 0     DT Original    0.7076     0.2039  0.1585    0.1783
# 1  DT Basic SMOTE    0.6293     0.1953  0.2728    0.2276
# 2  DT Tuned SMOTE    0.6312     0.1945  0.2680    0.2254
#
# ...
# COMPARISON: LOGISTIC REGRESSION vs DECISION TREE
# ...
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0  Original Imbalanced    0.7998     0.0000  0.0000    0.0000
# ...

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ## 6. Deployment
